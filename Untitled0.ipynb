# %% [markdown]
# <a href="https://colab.research.google.com/github/UjfFeds/could_computing_lab2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a.	Python code for text handling

# %%
# Text Handling Example
text = "Cloud computing is changing the world!"
word_count = len(text.split())
print(f"Text: {text}")
print(f"Word Count: {word_count}")
# Out:
# Text: Cloud computing is changing the world!
# Word Count: 6

# %% [markdown]
# b.	Python code for file handling

# %%
# File Handling Example
filename = "example.txt"

# Writing to a file
with open(filename, "w") as file:
    file.write("This is a sample file for cloud computing lab.")

# Reading from a file
with open(filename, "r") as file:
    content = file.read()

print("File content:", content)
# Out:
# File content: This is a sample file for cloud computing lab.

# %% [markdown]
# c.	Python code for image processing

# %%
# Image Processing Example using OpenCV
import cv2
from google.colab.patches import cv2_imshow

# Load an image (Upload one first using the upload cell below)
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
    img = cv2.imread(fn)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2_imshow(gray)
# Out:
#      <input type="file" id="files-ebb41f3d-956e-445c-b4f9-0f05578bd882" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebb41f3d-956e-445c-b4f9-0f05578bd882">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# d.	Python code for handling video files

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload a video file
uploaded = files.upload()

for fn in uploaded.keys():
    cap = cv2.VideoCapture(fn)
    if not cap.isOpened():
        print("Error opening video file")
    else:
        print(f"Video {fn} loaded successfully!")

        # Grid parameters
        rows, cols = 10, 10
        frame_width, frame_height = 64, 64  # Resize for fitting grid
        frame_list = []

        # Read and store 100 frames
        for _ in range(rows * cols):
            ret, frame = cap.read()
            if not ret:
                break
            resized_frame = cv2.resize(frame, (frame_width, frame_height))
            frame_list.append(resized_frame)

        cap.release()

        # Fill the grid with black images if less than 100 frames
        while len(frame_list) < rows * cols:
            frame_list.append(np.zeros((frame_height, frame_width, 3), dtype=np.uint8))

        # Convert to grid
        grid_rows = []
        for i in range(rows):
            row = np.hstack(frame_list[i*cols:(i+1)*cols])
            grid_rows.append(row)

        grid_image = np.vstack(grid_rows)

        # Display the grid image
        cv2_imshow(grid_image)
# Out:
#      <input type="file" id="files-5ca1dd59-a2de-4a80-9401-2ffee026e16d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ca1dd59-a2de-4a80-9401-2ffee026e16d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
